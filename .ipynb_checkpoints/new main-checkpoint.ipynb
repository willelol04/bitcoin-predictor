# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, cross_val_score


import sys
from packaging import version
import sklearn

# Check Python version
if sys.version_info < (3, 7):
    raise ValueError(f"Python version must be 3.7 or higher. Found: {sys.version_info.major}.{sys.version_info.minor}")

# Check Scikit-learn version
if version.parse(sklearn.__version__) < version.parse("1.0.1"):
    raise ValueError(f"Scikit-learn version must be 1.0.1 or higher. Found: {sklearn.__version__}")

print("Environment checks passed: Python and Scikit-learn versions meet requirements.")


from pathlib import Path  # Importing the Path class from the pathlib module to handle file system paths
import pandas as pd  # Importing pandas as pd for data manipulation and analysis
import tarfile  # Importing the tarfile module to work with tar archive files
import urllib.request  # Importing urllib.request to handle URL operations

def load_bitcoin_data():
    bitcoin_path = Path("btcusd_1-min_data.csv")

    if not bitcoin_path.is_file():
       print("NOT FOUND")
        
    return pd.read_csv(Path("btcusd_1-min_data.csv"))

bitcoin = load_bitcoin_data()
print("Bitcoin data loaded successfully.")
# Out:
# Environment checks passed: Python and Scikit-learn versions meet requirements.
# Bitcoin data loaded successfully.

# %%
# Visa de första raderna
print(bitcoin.head())

# Se datatyper och om det finns saknade värden (nulls)
print(bitcoin.info(show_counts=True))

# Se statistisk sammanfattning (min, max, standardavvikelse)
print(bitcoin.describe())
# Out:
#       Timestamp  Open  High   Low  Close  Volume
# 0  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 1  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 2  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 3  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 4  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# <class 'pandas.DataFrame'>
# RangeIndex: 7559696 entries, 0 to 7559695
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Timestamp  7559696 non-null  float64
#  1   Open       7559696 non-null  float64
#  2   High       7559696 non-null  float64
#  3   Low        7559696 non-null  float64
#  4   Close      7559696 non-null  float64
#  5   Volume     7559696 non-null  float64
# dtypes: float64(6)
# memory usage: 346.1 MB
# None
#           Timestamp          Open          High           Low         Close  \
# count  7.559696e+06  7.559696e+06  7.559696e+06  7.559696e+06  7.559696e+06
# mean   1.552209e+09  2.308835e+04  2.309645e+04  2.308009e+04  2.308837e+04
# std    1.309468e+08  3.117295e+04  3.118133e+04  3.116452e+04  3.117298e+04
# min    1.325412e+09  3.800000e+00  3.800000e+00  3.800000e+00  3.800000e+00
# 25%    1.438807e+09  4.535000e+02  4.536000e+02  4.533200e+02  4.535000e+02
# 50%    1.552203e+09  7.874870e+03  7.880155e+03  7.869275e+03  7.874870e+03
# 75%    1.665598e+09  3.704051e+04  3.706000e+04  3.702035e+04  3.704100e+04
# max    1.779063e+09  1.262020e+05  1.262720e+05  1.261580e+05  1.262020e+05
#
#              Volume
# count  7.559696e+06
# mean   5.023973e+00
# std    2.173496e+01
# min    0.000000e+00
# 25%    2.118935e-02
# 50%    4.514899e-01
# 75%    2.825693e+00
# max    5.853852e+03

# %%
# 1. Konvertera Timestamp (Unix) till datetime och sätt som index
bitcoin['Datetime'] = pd.to_datetime(bitcoin['Timestamp'], unit='s')
bitcoin.set_index('Datetime', inplace=True)
bitcoin.drop(columns=['Timestamp'], inplace=True)

# 2. Skapa Target (nästa minuts stängningspris)
bitcoin['Target'] = bitcoin['Close'].shift(-1)

# 3. Skapa dina Features
bitcoin['Return_1m'] = bitcoin['Close'].pct_change()        # Avkastning senaste minuten
bitcoin['MA_5'] = bitcoin['Close'].rolling(window=5).mean()   # 5 minuters rörligt medelvärde
bitcoin['MA_30'] = bitcoin['Close'].rolling(window=30).mean() # 30 minuters rörligt medelvärde

# Ta bort rader med NaN (skapade av skiftningar och rörliga medelvärden)
bitcoin.dropna(inplace=True)

print("Features skapade. Ny form på data:", bitcoin.shape)
# Out:
# Features skapade. Ny form på data: (7559666, 9)

# %%
# Se till att indexet är datetime (det gjorde vi i tidigare steg)
# Vi skapar en ny dataframe för dagsdata
df_daily = pd.DataFrame()

df_daily['Open'] = bitcoin['Open'].resample('D').first()
df_daily['High'] = bitcoin['High'].resample('D').max()
df_daily['Low'] = bitcoin['Low'].resample('D').min()
df_daily['Close'] = bitcoin['Close'].resample('D').last()
df_daily['Volume'] = bitcoin['Volume'].resample('D').sum()

# Ta bort eventuella dagar helt utan data (t.ex. om det saknades historik)
df_daily.dropna(inplace=True)

#--------------
# 1. Skapa morgondagens pris
df_daily['Next_Close'] = df_daily['Close'].shift(-1)

# 2. Skapa Target: 1 om nästa dags pris är högre än idag, annars 0
df_daily['Target'] = (df_daily['Next_Close'] > df_daily['Close']).astype(int)

# --- BEFINTLIGA FEATURES ---
df_daily['Return_1d'] = df_daily['Close'].pct_change()
df_daily['MA_5'] = df_daily['Close'].rolling(window=5).mean()   # 5-dagars medelvärde
df_daily['MA_20'] = df_daily['Close'].rolling(window=20).mean() # 20-dagars medelvärde

# --- NYA FEATURES ---

# 3. Pris-spreads (Hur såg dagens handel ut?)
# Hög volatilitet under dagen kan skvallra om osäkerhet på marknaden
df_daily['High_Low_Spread'] = df_daily['High'] - df_daily['Low']
# Visar om dagen stängde högre eller lägre än den öppnade (dagens momentum)
df_daily['Close_Open_Spread'] = df_daily['Close'] - df_daily['Open']

# 4. Volatilitet (Rullande standardavvikelse)
# Mäts på de senaste 5 dagarnas procentuella avkastning
df_daily['Volatility_5d'] = df_daily['Return_1d'].rolling(window=5).std()

# 5. Historisk Avkastning (Lagged Returns)
# Modellen kan titta på om priset gick upp igår, eller i förrgår
df_daily['Return_Lag1'] = df_daily['Return_1d'].shift(1) # Igår
df_daily['Return_Lag2'] = df_daily['Return_1d'].shift(2) # I förrgår

# 6. Avstånd till rörliga medelvärden
# Istället för att bara ge modellen MA_5 (ett enormt dollar-värde), 
# ger vi den procentuella skillnaden mellan dagens pris och medelvärdet
df_daily['Dist_to_MA_5'] = (df_daily['Close'] - df_daily['MA_5']) / df_daily['MA_5']
df_daily['Dist_to_MA_20'] = (df_daily['Close'] - df_daily['MA_20']) / df_daily['MA_20']


# Rensa bort rader med NaN som skapades av skiftningar och medelvärden
df_daily.dropna(inplace=True)

# Uppdatera listan över features så att de nya kolumnerna kommer med!
feature_cols = [
    'Open', 'High', 'Low', 'Close', 'Volume', 
    'Return_1d', 'MA_5', 'MA_20',
    'High_Low_Spread', 'Close_Open_Spread', 
    'Volatility_5d', 'Return_Lag1', 'Return_Lag2',
    'Dist_to_MA_5', 'Dist_to_MA_20'
]

# Separera i X och y
X = df_daily[feature_cols]
y = df_daily['Target']

print("Klassfördelning (Hur många dagar gick upp (1) vs ner (0)):")
print(y.value_counts())
print(f"\nAntal features vi nu skickar till modellen: {X.shape[1]}")

print(f"Datasetet har ändrats från 7,5 miljoner rader till {df_daily.shape[0]} dagar!")
# Out:
# Klassfördelning (Hur många dagar gick upp (1) vs ner (0)):
# Target
# 1    2781
# 0    2451
# Name: count, dtype: int64
#
# Antal features vi nu skickar till modellen: 15
# Datasetet har ändrats från 7,5 miljoner rader till 5232 dagar!

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Skapa nya klassificeringsmodeller
log_reg = LogisticRegression(max_iter=100)

#forest_clf = RandomForestClassifier(n_estimators=5000, max_depth=7, random_state=42, n_jobs=-1)
#forest_clf = RandomForestClassifier(   n_estimators=1000,    max_depth=5,  min_samples_leaf=15, # Kräver minst 15 dagar i varje slutsatsrandom_state=42, n_jobs=-1)

# 'class_weight' låter dig bestämma hur viktiga klasserna är.
# Här säger vi att klass 0 (Ner) är 2 gånger viktigare att inte missa.
forest_clf = RandomForestClassifier(
    n_estimators=2000, 
    max_depth=7,                  # Låt den gå till 7 så den hittar lite finare mönster
    min_samples_leaf=5,          # Kräver minst 10 dagar per slutsats för stabilitet
    class_weight={0: 0.2, 1: 1.0}, # Straffar felgissningar med 30% extra tyngd
    random_state=42, 
    n_jobs=-1
)
# Förbered vår Pipeline (skalning behövs fortfarande för Logistisk Regression)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# Vi bygger en pipeline för hela flödet
pipe_log = Pipeline([('scaler', StandardScaler()), ('log_reg', log_reg)])
pipe_forest = Pipeline([('scaler', StandardScaler()), ('forest_clf', forest_clf)])

# Tidsserie-split
tscv = TimeSeriesSplit(n_splits=5)

# Kör korsvalidering med 'accuracy' som poängsättning
print("Kör korsvalidering för Logistisk Regression...")
log_scores = cross_val_score(pipe_log, X, y, cv=tscv, scoring="accuracy")

print("Kör korsvalidering för Random Forest Classifier...")
forest_scores = cross_val_score(pipe_forest, X, y, cv=tscv, scoring="accuracy")

print(f"\nLogistic Regression Accuracy: {log_scores.mean():.4f} (Std: {log_scores.std():.4f})")
print(f"Random Forest Classifier Accuracy: {forest_scores.mean():.4f} (Std: {forest_scores.std():.4f})")
# Out:
# Kör korsvalidering för Logistisk Regression...
# Kör korsvalidering för Random Forest Classifier...
#
# Logistic Regression Accuracy: 0.4924 (Std: 0.0164)
# Random Forest Classifier Accuracy: 0.5089 (Std: 0.0139)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Kronologisk split
split_idx = int(len(X) * 0.8)
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

# Vi tränar vår Random Forest Classifier
pipe_forest.fit(X_train, y_train)
y_pred = pipe_forest.predict(X_test)

# Skapa förvirringsmatrisen
cm = confusion_matrix(y_test, y_pred)

# Rita upp matrisen snyggt
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Ner (0)', 'Upp (1)'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix - Hur bra modellen prickar Upp/Ner')
plt.show()

# Skriv ut slutgiltig accuracy på testdatan
print(f"Slutgiltig Accuracy på testdatan: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Slutgiltig Accuracy på testdatan: 0.5053

# %%
import numpy as np
import matplotlib.pyplot as plt

# Hämta importances från Random Forest-modellen inuti vår pipeline
importances = pipe_forest.named_steps['forest_clf'].feature_importances_

# Sortera dem i fallande ordning
indices = np.argsort(importances)[::-1]
sorted_features = [feature_cols[i] for i in indices]

plt.figure(figsize=(10, 6))
plt.bar(range(X.shape[1]), importances[indices], color='teal', align='center')
plt.xticks(range(X.shape[1]), sorted_features, rotation=45)
plt.title('Feature Importance - Vilka indikatorer väger tyngst?')
plt.ylabel('Relativ betydelse')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Hämta sannolikheterna för att det blir en "Upp-dag" (klass 1)
y_probs = pipe_forest.predict_proba(X_test)[:, 1]

# Beräkna falsk positiv-takt och sann positiv-takt
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
auc_score = roc_auc_score(y_test, y_probs)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC-kurva (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Slumpmässig gissning (0.50)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Falsk positiv-takt (False Positive Rate)')
plt.ylabel('Sann positiv-takt (True Positive Rate)')
plt.title('ROC-kurva för Bitcoin-prediktion')
plt.legend(loc="lower right")
plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# %%
# Skapa en kopia av test-datan för att räkna ut avkastning
strategy_df = pd.DataFrame(index=y_test.index)
strategy_df['Market_Return'] = X_test['Return_1d']
strategy_df['Predicted_Signal'] = y_pred

# Om modellen gissar 1 får vi marknadens avkastning nästa dag. 
# Vi skiftar signalen med 1 eftersom vi agerar på signalen inför NÄSTA dag.
strategy_df['Strategy_Return'] = strategy_df['Market_Return'] * strategy_df['Predicted_Signal'].shift(1)

# Fyll i första raden som annars blir NaN
strategy_df.fillna(0, inplace=True)

# Beräkna kumulativ avkastning (procentuell utveckling över tid)
cum_market = (1 + strategy_df['Market_Return']).cumprod() - 1
cum_strategy = (1 + strategy_df['Strategy_Return']).cumprod() - 1

# Plotta resultatet
plt.figure(figsize=(14, 7))
plt.plot(cum_market.index, cum_market * 100, label='Köpa och Behålla (Buy & Hold)', color='black', alpha=0.6)
plt.plot(cum_strategy.index, cum_strategy * 100, label='Följa Modellens Signaler (Strategi)', color='green', linewidth=2)
plt.title('Simulering: Modellens Strategi vs Köpa & Behålla (Procentuell avkastning)')
plt.xlabel('Datum')
plt.ylabel('Avkastning (%)')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# %%
from sklearn.metrics import classification_report

# Skriv ut en detaljerad rapport för vår Random Forest
rapport = classification_report(y_test, y_pred, target_names=['Ner/Stilla (0)', 'Upp (1)'])

print("--- DETALJERAD ACCURACY-RAPPORT ---")
print(rapport)
# Out:
# --- DETALJERAD ACCURACY-RAPPORT ---
#                 precision    recall  f1-score   support
#
# Ner/Stilla (0)       0.48      0.17      0.25       512
#        Upp (1)       0.51      0.82      0.63       535
#
#       accuracy                           0.51      1047
#      macro avg       0.50      0.50      0.44      1047
#   weighted avg       0.50      0.51      0.45      1047

# %%
import seaborn as sns

# Hämta modellens exakta procentsatser för "Upp" (klass 1)
y_probs = pipe_forest.predict_proba(X_test)[:, 1]

plt.figure(figsize=(10, 6))

# Plotta vad modellen gissade när det FAKTISKT gick upp (grönt)
sns.histplot(y_probs[y_test == 1], bins=30, color='green', alpha=0.5, label='Dagar som gick Upp', kde=True)

# Plotta vad modellen gissade när det FAKTISKT gick ner (rött)
sns.histplot(y_probs[y_test == 0], bins=30, color='red', alpha=0.5, label='Dagar som gick Ner', kde=True)

# Rita en linje vid 50% (tröskelvärdet för att gissa 1 eller 0)
plt.axvline(0.5, color='black', linestyle='--', label='50% Tröskel')

plt.title('Hur säker är modellen på sina gissningar?')
plt.xlabel('Sannolikhet att priset går Upp (Enligt modellen)')
plt.ylabel('Antal dagar')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)
plt.show()

# %%
import pandas as pd

# 1. Bygg om dagsdatan (utan att ta bort sista dagen)
df_latest = pd.DataFrame()
df_latest['Open'] = bitcoin['Open'].resample('D').first()
df_latest['High'] = bitcoin['High'].resample('D').max()
df_latest['Low'] = bitcoin['Low'].resample('D').min()
df_latest['Close'] = bitcoin['Close'].resample('D').last()
df_latest['Volume'] = bitcoin['Volume'].resample('D').sum()

# 2. Skapa dina features
df_latest['Return_1d'] = df_latest['Close'].pct_change()
df_latest['MA_5'] = df_latest['Close'].rolling(window=5).mean()
df_latest['MA_20'] = df_latest['Close'].rolling(window=20).mean()
df_latest['High_Low_Spread'] = df_latest['High'] - df_latest['Low']
df_latest['Close_Open_Spread'] = df_latest['Close'] - df_latest['Open']
df_latest['Volatility_5d'] = df_latest['Return_1d'].rolling(window=5).std()
df_latest['Return_Lag1'] = df_latest['Return_1d'].shift(1)
df_latest['Return_Lag2'] = df_latest['Return_1d'].shift(2)
df_latest['Dist_to_MA_5'] = (df_latest['Close'] - df_latest['MA_5']) / df_latest['MA_5']
df_latest['Dist_to_MA_20'] = (df_latest['Close'] - df_latest['MA_20']) / df_latest['MA_20']

# Se till att listan med features ser exakt ut som den modellen tränades på
feature_cols = [
    'Open', 'High', 'Low', 'Close', 'Volume', 
    'Return_1d', 'MA_5', 'MA_20',
    'High_Low_Spread', 'Close_Open_Spread', 
    'Volatility_5d', 'Return_Lag1', 'Return_Lag2',
    'Dist_to_MA_5', 'Dist_to_MA_20'
]

# 3. Plocka ut den ALLRA SISTA dagen i historiken (vi tar bort Target här)
last_day_data = df_latest[feature_cols].iloc[-1:]

# Skriv ut vilket datum modellen gissar utifrån
print(f"Modellen tittar på data från: {last_day_data.index[0].strftime('%Y-%m-%d')}")
print(f"Stängningspris den dagen: {last_day_data['Close'].values[0]:.2f} USD\n")

# 4. Låt modellen förutsäga nästa dag!
# Ny kod utan varning (vi lägger till .values):
prediction = forest_clf.predict(last_day_data.values)
probabilities = forest_clf.predict_proba(last_day_data.values)

# 5. Skriv ut det spännande resultatet
print("🔮 --- PREDIKTION FÖR NÄSTA DAG --- 🔮")
if prediction[0] == 1:
    print("👉 Modellen gissar: UPP 🟢 (Priset kommer stänga högre)")
    # probabilities[0][1] är chansen för klass 1 (Upp)
    print(f"👉 Modellen är {probabilities[0][1] * 100:.1f}% säker på sin gissning.")
else:
    print("👉 Modellen gissar: NER eller STILLA 🔴 (Priset kommer stänga lägre)")
    # probabilities[0][0] är chansen för klass 0 (Ner)
    print(f"👉 Modellen är {probabilities[0][0] * 100:.1f}% säker på sin gissning.")
# Out:
# Modellen tittar på data från: 2026-05-18
# Stängningspris den dagen: 77180.00 USD
#
# 🔮 --- PREDIKTION FÖR NÄSTA DAG --- 🔮
# 👉 Modellen gissar: NER eller STILLA 🔴 (Priset kommer stänga lägre)
# 👉 Modellen är 50.2% säker på sin gissning.
